# %% [markdown]
# # Final Assignment

# %% [markdown]
# STT: 34
#
# **Member**
#
# 18120374 Nguyễn Minh Hiếu
#
# 18120384 Nguyễn Văn Hoài

# %% [markdown]
# Thư viện cần dùng thêm:
#    * **nltk**: để schemming
#
#    * **re** để làm chuẩn

# %%
import nltk
#nltk.download()
#Hiện bảng Chọn popular

# %% [markdown]
# Lợi ích:
# * Nếu tìm được công thức thì công ty sản xuất có thể tự động hóa quá trình rút trích ý kiến thích / không thích từ các đoạn đánh giá của người dùng
# * Giúp công ty đánh giá được hiệu quả công việc. (Ở đây là AMAZON có thể kiểm tra sản phẩm được vận chuyển có đúng ý muốn khách hàng hay không)

# %% [markdown]
# # Bước 1: Thu thập dữ liệu
# Đưa một link sản phẩm bất kì và kiểm tra phần đánh giá của khách hàng.
# * Đánh giá sẽ phân loại: ***postive* : 1**  và ***critical* : 0**
# * Mỗi trang gồm 10 đánh giá, ta duyệt 250 trang cho mỗi loại đánh giá. Vậy tổng cộng 10x270x2 = 5400 đánh giá

# %%
import requests
import pandas as pd
import numpy as np
import time
import sklearn
from bs4 import BeautifulSoup
from selenium import webdriver
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# %%
url = 'https://www.amazon.com/NETGEAR-R6700-Nighthawk-Gigabit-Ethernet/dp/B00R2AZLD2/ref=gbps_img_m-9_475e_daf1a9de?smid=ATVPDKIKX0DER&pf_rd_p=5d86def2-ec10-4364-9008-8fbccf30475e&pf_rd_s=merchandised-search-9&pf_rd_t=101&pf_rd_i=15529609011&pf_rd_m=ATVPDKIKX0DER&pf_rd_r=B32H66M6KMBDBB378HQH&th=1'
browser = webdriver.Chrome(executable_path='./chromedriver.exe') 
browser.maximize_window()
browser.get(url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-fb6244768fd0> in <module>
#       1 url = 'https://www.amazon.com/NETGEAR-R6700-Nighthawk-Gigabit-Ethernet/dp/B00R2AZLD2/ref=gbps_img_m-9_475e_daf1a9de?smid=ATVPDKIKX0DER&pf_rd_p=5d86def2-ec10-4364-9008-8fbccf30475e&pf_rd_s=merchandised-search-9&pf_rd_t=101&pf_rd_i=15529609011&pf_rd_m=ATVPDKIKX0DER&pf_rd_r=B32H66M6KMBDBB378HQH&th=1'
#       2 browser = webdriver.Chrome(executable_path='./chromedriver.exe')
# ----> 3 browser.maximize_window()
#       4 browser.get(url)
#
# D:\App\New folder (3)\lib\site-packages\selenium\webdriver\remote\webdriver.py in maximize_window(self)
#     735             command = Command.MAXIMIZE_WINDOW
#     736             params = {'windowHandle': 'current'}
# --> 737         self.execute(command, params)
#     738
#     739     def fullscreen_window(self):
#
# D:\App\New folder (3)\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# D:\App\New folder (3)\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# D:\App\New folder (3)\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# D:\App\New folder (3)\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77             )
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# D:\App\New folder (3)\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# D:\App\New folder (3)\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# D:\App\New folder (3)\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# D:\App\New folder (3)\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# D:\App\New folder (3)\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\App\New folder (3)\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# D:\App\New folder (3)\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# D:\App\New folder (3)\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# D:\App\New folder (3)\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# D:\App\New folder (3)\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# `Phrases` Gồm các đánh giá  `status` loại đánh giá

# %%
phrases = []
status = []

# %%
#Click See all review
review_page = browser.find_element_by_link_text('See all reviews').click();

# %%
#Choose Verified purchase only
reviewer_types = browser.find_elements_by_css_selector('#reviewer-type-dropdown option')
for reviewer_type in reviewer_types:
    if "Verified purchase only" in reviewer_type.text:
        reviewer_type.click()
        break

# %%
#Positive first
comment_types = browser.find_elements_by_css_selector('#star-count-dropdown option')
for comment_type in comment_types:
    if "All positive" in comment_type.text:
        comment_type.click()
        break

# %%
#Page content
for i in range(0,3):
    time.sleep(3)
    html_text = browser.page_source
    tree = BeautifulSoup(html_text, 'html.parser')
    reviews = tree.find_all('div',{'data-hook':'review'})
    for review in reviews:
        content = review.find('a', {'data-hook': 'review-title'})
        phrases.append(content.text.strip())
        status.append(1)
    browser.find_element_by_class_name('a-last').click()

# %%
# then Critical
comment_types = browser.find_elements_by_css_selector('#star-count-dropdown option')
for comment_type in comment_types:
    if "All critical" in comment_type.text:
        comment_type.click()
        break

# %%
#Page content
for i in range(0,3):
    time.sleep(3)
    html_text = browser.page_source
    tree = BeautifulSoup(html_text, 'html.parser')
    reviews = tree.find_all('div',{'data-hook':'review'})
    for review in reviews:
        content = review.find('a', {'data-hook': 'review-title'})
        phrases.append(content.text.strip())
        status.append(0)
    browser.find_element_by_class_name('a-last').click()

# %%
Data = pd.DataFrame(
    {'Para': phrases,
     'Stt': status
    }
)

# %% [markdown]
# **Kiểm tra data**
#
# Lưu data vào file "data.csv"

# %%
Data.shape

# %%
#Data.to_csv('data.csv',index = False,encoding='utf-16',sep = '\t')

# %% [markdown]
# * Sử dụng file data.csv có sẵn
# * cột Para sẽ chứa các đánh giá
# * cột status gồm loại đánh giá tương ứng (1: positive - 0: critical)

# %%
data = pd.read_csv('data.csv',encoding='utf-16',sep = '\t')
#data.head()
data[data.index == 2458]
# Out:
#                 Para  Stt
# 2458  Great Product!    1

# %%
data.shape
# Out:
# (5400, 2)

# %% [markdown]
# Dữ liệu trùng lặp

# %%
data.duplicated().sum()
# Out:
# 326

# %% [markdown]
# Loại bỏ trùng lặp

# %%
data.drop_duplicates(subset=None, keep='first', inplace=True)
data.shape
# Out:
# (5074, 2)

# %% [markdown]
# Kiểm tra thiếu dữ liệu

# %%
data.isna().sum()
# Out:
# Para    0
# Stt     0
# dtype: int64

# %% [markdown]
# Kiểm tra độ cân bằng dữ liệu

# %%
data.Stt.mean()
# Out:
# 0.48817500985415846

# %%
y_sr = data["Stt"] # sr là viết tắt của series
X_df = data.drop("Stt", axis=1)

# %%
train_X_df, val_X_df, train_y_sr, val_y_sr = train_test_split(X_df, y_sr, test_size=0.3, 
                                                              stratify=y_sr, random_state=0)

# %%
train_X_df.shape
# Out:
# (3551, 1)

# %%
train_y_sr.shape
# Out:
# (3551,)

# %%
val_X_df.shape
# Out:
# (1523, 1)

# %%
val_y_sr.shape
# Out:
# (1523,)

# %% [markdown]
# # Bước 2 tiền xử lý dữ liệu

# %% [markdown]
# Ta cần thực hiện các bước: loại phần thừa, áp dụng *stemming*
# * Stemming: đưa các từ có hình thức tương đồng nhau về từ gốc (Ở đây ta chưa bàn về ngữ cảnh).
# * Phần thừa như dấu câu, icon.
#
# Vì ta sử dụng tiếng Anh nên các từ có dấu (khác a-z A-Z) cũng sẽ bị loại bỏ

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re

#nltk.download()
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.neural_network import MLPClassifier 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import  StandardScaler

# %%
#Steeming English only
englishStemmer=SnowballStemmer("english")

# %% [markdown]
# File `stop_word.txt` có gồm nhiều từ cách nhau dấu ','

# %%
stop_word = []
with open("stop_word.txt",encoding="utf-8") as f:
    text = f.read()
    for word in text.split(',') :
        stop_word.append(word.strip('\n'))
    f.close()
stop_word
# Out:
# ['router',
#  'i',
#  'you',
#  'we',
#  'they',
#  'he',
#  'she',
#  'it',
#  'my',
#  'your',
#  'her',
#  'his',
#  'him',
#  'their',
#  'them',
#  'me',
#  'our',
#  'us',
#  'its',
#  'ourselves',
#  'themselves',
#  'itself',
#  'be',
#  'is',
#  'am',
#  'do',
#  'does',
#  'did',
#  'was',
#  'were',
#  'has',
#  'have',
#  'had',
#  'will',
#  'would',
#  'can',
#  'could',
#  'should',
#  'a',
#  'an',
#  't',
#  'd',
#  've',
#  's',
#  're',
#  'm',
#  'one',
#  'with',
#  'in',
#  'of',
#  'for',
#  'on',
#  'at',
#  'to',
#  'between',
#  'from',
#  'this',
#  'that',
#  'these',
#  'those',
#  'as',
#  'and',
#  'the',
#  'very',
#  'quite',
#  'totally\nnow',
#  'then',
#  'just',
#  'really',
#  'thing',
#  'ever']

# %%
len(stop_word)
# Out:
# 71

# %% [markdown]
# File `check.txt` có gồm nhiều dòng, mỗi dòng gồm [*từ tối giản*] : [*các từ cần đưa về tối giản*] được đưa vào dict_check

# %%
dict_check = {}
with open("check.txt", newline='') as f :
    Lines = f.readlines()
for line in Lines:
    sep = line.strip('\r\n').split(':')
    list_word = sep[1].split(',')
    dict_check[sep[0]] = list_word

# %%
def get_key(dict_X,value):
    for k, v in dict_X.items(): 
        for item in v:
            if(value == item):
                return k
    return False

# %% [markdown]
# Hàm `Recontruct_Sentence` để xử lý câu:
#    * Làm chuẩn câu
#    * Tối giản từ
#    * ghép các từ lại

# %%
def Recontruct_Sentence(sentence):
    sentence = re.sub('[^A-Za-z]',' ', sentence) #thay thế tất cả thành phần không thuộc bảng chữ cái thành dấu " "
    sentence = sentence.lower()
    token_words=word_tokenize(sentence)
    stem_sentence=[]                       #tạo một list gồm các từ sau khi đã stemming" 
    for word in token_words:
        
        if (get_key(dict_check,word)!=False): #tối giản một số từ ngoại lệ
            word = get_key(dict_check,word)
            
        word = englishStemmer.stem(word)
        
        if(word not in stop_word):         #loại bỏ stop_word                
            stem_sentence.append(word)
            stem_sentence.append(" ")
    return "".join(stem_sentence)

# %% [markdown]
# Class `trans_Sentence` sẽ chuyển DataFrame đầu vào thành DataFrame tối giản với phương thức *transform*.

# %%
#Test pipeline
class trans_Sentence(BaseEstimator, TransformerMixin):
    
    def fit(self, X_df, y=None):
        return self
    def transform(self, X_df, y=None):
        # YOUR CODE HERE
        optimize= []
        self = X_df.copy()
        sentence_s = self.Para
        for sentence in sentence_s:
            optimize.append(Recontruct_Sentence(sentence))
        self.drop(['Para'],axis = 1)
        self['Para'] = optimize
        return self

# %% [markdown]
# Kiểm tra `trans_Sentence()`

# %%
tran = trans_Sentence()
test_trans_Sentence = tran.fit_transform(train_X_df)
test_trans_Sentence.head()
# Out:
#                                                    Para
# 1374                                              best
# 2515            good set up took longer than necessari
# 2525                                except easi set up
# 2967  tech support what joke regist receiv prioriti ...
# 4210                                  abysm wifi speed

# %% [markdown]
# ---
# # Chú ý

# %%
test_trans_Sentence[test_trans_Sentence['Para'] == ""]
# Out:
#      Para
# 1785
# 1448
# 1520
# 2510

# %% [markdown]
# Sau khi áp dụng `trans_Sentence()`, một số review sẽ bị rỗng do review chỉ chứa từ thừa, vẫn chưa xử lý được có thể sẽ issue cái này.

# %% [markdown]
# ---
# TfidfVectorizer() tham khảo ở [link](https://thorpham.github.io/blog/2018/04/14/setmentation/) và [doc](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html)
#
# Class `toarray_Tidf` gồm các tham số đầu vào dành cho TfidfVectorizer().
# * fit: dùng `TfidfVectorizer()` fit tập dữ liệu đầu vào
# * transform dùng `TfidfVectorizer()` biến dữ liệu đầu vào thành mảng numpy các vector dựa trên fit

# %%
class toarray_Tidf(BaseEstimator, TransformerMixin):
    def __init__(self,max_features = None, min_df = 1, ngram_range = None, stop_words = None):
        self.max_features = max_features
        self.min_df = min_df
        self.ngram_range = ngram_range
        self.stop_words = stop_words 
        vect = TfidfVectorizer(max_features =  max_features, min_df = min_df, ngram_range =  ngram_range, stop_words =  self.stop_words)
        self.vect = vect
    def fit(self, X_df, y=None):
        self.vect.fit(X_df.Para)
        return self
    def transform(self, X_df, y=None):
        # YOUR CODE HERE
        return self.vect.transform(X_df.Para).toarray()

# %% [markdown]
# Kiểm tra toarray_Tidf()

# %%
test_toarray_Tidf = toarray_Tidf(ngram_range = (1,1),stop_words = 'english' )
test = test_toarray_Tidf.fit_transform(test_trans_Sentence) 
total = len(test[0])
total
# Out:
# 1625

# %% [markdown]
# Vậy Bag Of Word của ta gồm **1630** từ đơn.

# %% [markdown]
# ---
# # Bước 3: Xây dựng mạng `Neural Network` và `full_pipeline`

# %%
neural = MLPClassifier(hidden_layer_sizes = 10, activation='tanh', solver='lbfgs', random_state=0, max_iter = 2750)
tidf = toarray_Tidf(stop_words = {'english'}, ngram_range = (1,1))
full_pipeline= make_pipeline(trans_Sentence(), tidf, neural)

full_pipeline
# Out:
# Pipeline(steps=[('trans_sentence', trans_Sentence()),
#                 ('toarray_tidf',
#                  toarray_Tidf(ngram_range=(1, 1), stop_words={'english'})),
#                 ('mlpclassifier',
#                  MLPClassifier(activation='tanh', hidden_layer_sizes=10,
#                                max_iter=2750, random_state=0,
#                                solver='lbfgs'))])

# %% [markdown]
# ---
# # Kiểm tra Overfitting

# %% [markdown]
# Để mọi tham số là mặc định

# %%
full_pipeline.set_params()
# Out:
# Pipeline(steps=[('trans_sentence', trans_Sentence()),
#                 ('toarray_tidf',
#                  toarray_Tidf(ngram_range=(1, 1), stop_words={'english'})),
#                 ('mlpclassifier',
#                  MLPClassifier(activation='tanh', hidden_layer_sizes=10,
#                                max_iter=2750, random_state=0,
#                                solver='lbfgs'))])

# %%
let_fit = full_pipeline.fit(train_X_df,train_y_sr)

# %%
(1- let_fit.score(train_X_df,train_y_sr))
# Out:
# 0.003379329766262984

# %%
(1- let_fit.score(val_X_df,val_y_sr))
# Out:
# 0.18056467498358508

# %% [markdown]
# Không tệ lắm!!!

# %%
full_pipeline.set_params(toarray_tidf__max_features= 200, mlpclassifier__hidden_layer_sizes = 3)
# Out:
# Pipeline(steps=[('trans_sentence', trans_Sentence()),
#                 ('toarray_tidf',
#                  toarray_Tidf(max_features=200, ngram_range=(1, 1),
#                               stop_words={'english'})),
#                 ('mlpclassifier',
#                  MLPClassifier(activation='tanh', hidden_layer_sizes=3,
#                                max_iter=2750, random_state=0,
#                                solver='lbfgs'))])

# %%
let_fit = full_pipeline.fit(train_X_df,train_y_sr)

# %%
(1- let_fit.score(train_X_df,train_y_sr))
# Out:
# 0.00647704871867083

# %%
(1- let_fit.score(val_X_df,val_y_sr))
# Out:
# 0.18516086671043996

# %%
num_max_features = [500,700,1100,None]
num_alpha = [0.1, 1, 10, 100, 1000]
num_min_df = [1,10,50,100,200]

# %%
train_errs = []
val_errs = []
best_val_err = float('inf')
best_alpha = None
best_min_df = None
for alpha in num_alpha:
    for min_df in num_min_df:
        full_pipeline.set_params(toarray_tidf__min_df= min_df, mlpclassifier__alpha=alpha)
        let_fit = full_pipeline.fit(train_X_df,train_y_sr)
        
        error = (1- let_fit.score(train_X_df,train_y_sr))*100
        train_errs.append(error)
        
        error = (1 - let_fit.score(val_X_df,val_y_sr))*100
        val_errs.append(error)
        
        if (error < best_val_err):
            best_val_err = error
            best_alpha = alpha
            best_min_df = min_df

# %%
train_errs
# Out:
# [0.3379329766262984,
#  0.3379329766262984,
#  0.3379329766262984,
#  0.3379329766262984,
#  0.3379329766262984,
#  1.0419600112644312,
#  1.0419600112644312,
#  1.0419600112644312,
#  1.0419600112644312,
#  1.0419600112644312,
#  5.913827090960289,
#  5.913827090960289,
#  5.913827090960289,
#  5.913827090960289,
#  5.913827090960289,
#  17.00929315685722,
#  17.00929315685722,
#  17.00929315685722,
#  17.00929315685722,
#  17.00929315685722,
#  48.831315122500705,
#  48.831315122500705,
#  48.831315122500705,
#  48.831315122500705,
#  48.831315122500705]

# %%
train_y_sr
train_errs_df = pd.DataFrame(data=np.array(train_errs).reshape(len(num_alpha), -1),
                             index=num_alpha, columns=num_min_df)
val_errs_df = pd.DataFrame(data=np.array(val_errs).reshape(len(num_alpha), -1), 
                           index=num_alpha, columns=num_min_df)
min_err = min(min(train_errs), min(val_errs))
max_err = max(max(train_errs), max(val_errs))
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.heatmap(train_errs_df, vmin=min_err, vmax=max_err, square=True, annot=True, 
            cbar=False, fmt='.1f', cmap='Reds')
plt.title('train errors'); plt.xlabel('num_min_df'); plt.ylabel('alpha')
plt.subplot(1, 2, 2)
sns.heatmap(val_errs_df, vmin=min_err, vmax=max_err, square=True, annot=True, 
            cbar=False, fmt='.1f', cmap='Reds')
plt.title('validation errors'); plt.xlabel('num_min_df'); plt.ylabel('alpha');

# %%
full_pipeline.set_params(toarray_tidf__min_df= best_min_df, mlpclassifier__alpha=best_alpha)
full_pipeline.fit(train_X_df,train_y_sr)
# Out:
# Pipeline(steps=[('trans_sentence', trans_Sentence()),
#                 ('toarray_tidf',
#                  toarray_Tidf(max_features=200, ngram_range=(1, 1),
#                               stop_words={'english'})),
#                 ('mlpclassifier',
#                  MLPClassifier(activation='tanh', alpha=10,
#                                hidden_layer_sizes=3, max_iter=2750,
#                                random_state=0, solver='lbfgs'))])

# %%
a = ["it does not work at all!","Perfect","i hate it","This thing is really bad!","Dont buy it","👍👍","👎👎","so so"]
test_dict = {'Para': a}
test = pd.DataFrame(test_dict )
full_pipeline.predict(test)
# Out:
# array([0, 1, 0, 0, 0, 1, 1, 1], dtype=int64)
